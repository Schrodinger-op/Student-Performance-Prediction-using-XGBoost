# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn import svm
# %matplotlib inline
sns.set_style("whitegrid")

df = pd.read_csv(r'C:\Users\satyam.barnwal\Desktop\Hackathon\Dataset1.csv')

# %%
sns.heatmap(df.corr(),cmap='RdYlGn')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Result
# It is the heatmap of the correlation of variable with eachother without any pre-processing.

# %%
my_label = LabelEncoder()
df1 = df.copy(deep=True)
df1["family_income"]= my_label.fit_transform(df1["family_income"])
df1["Medium_of_Instruction"]= my_label.fit_transform(df1["Medium_of_Instruction"])
df1["free_Time_After_School"]= my_label.fit_transform(df1["free_Time_After_School"])
df1["Student_Performance_level"] = my_label.fit_transform(df1["Student_Performance_level"])
df1["CWSN"]= my_label.fit_transform(df1["CWSN"])
df1["Attending_Remidal_Classes"]= my_label.fit_transform(df1["Attending_Remidal_Classes"])
df1["Hostel"]= my_label.fit_transform(df1["Hostel"])
df1["SMC_Frequency"]= my_label.fit_transform(df1["SMC_Frequency"])

df1["Type_of_social_media_used"]= my_label.fit_transform(df1["Type_of_social_media_used"])
df1["School_Toilet_Facility"]= my_label.fit_transform(df1["School_Toilet_Facility"])

df1["Playground_Availability"]= my_label.fit_transform(df1["Playground_Availability"]) 
df1["ICT_Facility"]= my_label.fit_transform(df1["ICT_Facility"]) 
df1["Library_Facility"]= my_label.fit_transform(df1["Library_Facility"]) 
df1["Dustbin_Facility"]= my_label.fit_transform(df1["Dustbin_Facility"])

df1["Electricity_Availability"]= my_label.fit_transform(df1["Electricity_Availability"]) 
df1["First_Aid_Box_Availability"]= my_label.fit_transform(df1["First_Aid_Box_Availability"]) 
df1["Teacher_Learning_Material_Availability"]= my_label.fit_transform(df1["Teacher_Learning_Material_Availability"]) 
df1["School_is_approach_by_all_weather_road"]= my_label.fit_transform(df1["School_is_approach_by_all_weather_road"])
df1["PTA_Meeting_Frequency"]= my_label.fit_transform(df1["PTA_Meeting_Frequency"])
df1["Location"]= my_label.fit_transform(df1["Location"])
df1["Board_Condition"]= my_label.fit_transform(df1["Board_Condition"])
df1["Parent_Status"]= my_label.fit_transform(df1["Parent_Status"])
df1["Father_working"]= my_label.fit_transform(df1["Father_working"])
df1["Mother_working"]= my_label.fit_transform(df1["Mother_working"])
df1["Mother_Education"]= my_label.fit_transform(df1["Mother_Education"])

df1["free_Time_After_School"]= my_label.fit_transform(df1["free_Time_After_School"])
df1["wants_to_take_higher_education"]= my_label.fit_transform(df1["wants_to_take_higher_education"])
df1["Internet_access_at_home"]= my_label.fit_transform(df1["Internet_access_at_home"])
df1["Study_Time_per_day"]= my_label.fit_transform(df1["Study_Time_per_day"])


df1
# Out:
#          Unnamed: 0       ID  present_days_out_off_100_instruction_days  \
# 0                 0        1                                     0.8559
# 1                 1        2                                     0.8563
# 2                 2        3                                     0.8320
# 3                 3        4                                     0.8409
# 4                 4        5                                     0.8487
# ...             ...      ...                                        ...
# 1999995     1999995  1999996                                     0.8396
# 1999996     1999996  1999997                                     0.7923
# 1999997     1999997  1999998                                     0.7100
# 1999998     1999998  1999999                                     0.7276
# 1999999     1999999  2000000                                     0.7813
#
#          Late_remark  family_income  CWSN  Hostel  Medium_of_Instruction  \
# ...

# %%
df1 = df1.drop('ID',axis = 1)
df1 = df1.drop('Unnamed: 0', axis = 1)
df1
# Out:
#          present_days_out_off_100_instruction_days  Late_remark  \
# 0                                           0.8559          5.0
# 1                                           0.8563          5.0
# 2                                           0.8320          2.0
# 3                                           0.8409          2.0
# 4                                           0.8487          4.0
# ...                                            ...          ...
# 1999995                                     0.8396          4.0
# 1999996                                     0.7923         10.0
# 1999997                                     0.7100         17.0
# 1999998                                     0.7276          4.0
# 1999999                                     0.7813         10.0
#
#          family_income  CWSN  Hostel  Medium_of_Instruction  \
# 0                    3     0       1                      4
# 1                    3     0       0                      1
# ...

# %%
def heat_map(corrs_mat):
    sns.set(style="white")
    f, ax = plt.subplots(figsize=(20, 20))
    mask = np.zeros_like(corrs_mat, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True 
    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(220, 10, as_cmap=True)
    sns.heatmap(corrs_mat, mask=mask, cmap=cmap, ax=ax)

variable_correlations = df1.corr()
#variable_correlations
heat_map(variable_correlations)
# Out:
# C:\Users\satyam.barnwal\AppData\Local\Temp\ipykernel_11956\498219553.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corrs_mat, dtype=np.bool)

# %% [markdown]
# Heat map of correalation after pre processing of data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(x='present_days_out_off_100_instruction_days', data=df1 )
plt.show()

# %% [markdown]
# It clearly shows that most of data lies between 0.7 to 0.9

# %%
sns.displot(x ='present_days_out_off_100_instruction_days',hue = 'Student_Performance_level', data = df,kde=True)
plt.title('present_days_out_off_100_instruction_days')
plt.show()

# %%
sns.countplot(x="Study_Time_per_day", hue="Student_Performance_level", data=df)
plt.show()

# %% [markdown]
# It shows that the student performed their best when they study between 4 to 6 hours.

# %%
fig = plt.gcf()

# Change seaborn plot size
fig.set_size_inches(13, 6)
sns.countplot(x ='Late_remark',hue = 'Student_Performance_level', data = df)
plt.show()

# %% [markdown]
#  The bar plot clearly discribe that after a certain point late remark worsen the performance. It is right skewed graph.

# %%
sns.countplot(x="wants_to_take_higher_education", hue="Student_Performance_level", data=df)
plt.show()

# %% [markdown]
# Students who wants to study further performed well because most of university asking for good academics.

# %%
sns.countplot(x="School_is_approach_by_all_weather_road", hue="Student_Performance_level", data=df)
plt.show()

# %% [markdown]
# Student who are able to attend the the school daily has higher performance.

# %%
sns.countplot(x="free_Time_After_School", hue="Student_Performance_level", data=df)
plt.show()

# %% [markdown]
# Student performed well if they have moderate free time because every students need self study.

# %%
sns.countplot(x="family_income", hue="Student_Performance_level", data=df)
plt.show()

# %% [markdown]
# Student has high performance if their family income more than a certain number because now they can access more facility and resources.

# %%
sns.countplot(x ='Medium_of_Instruction',hue = 'Student_Performance_level', data = df)
plt.show()

# %% [markdown]
# Here we can see that the English as a medium of instruction has the highest success rate and Bengali has worst success rate.

# %%
ax=sns.countplot(x ='Location',hue = 'Electricity_Availability', data = df)
for i in ax.containers:
    ax.bar_label(i,)
plt.show()

# %% [markdown]
# The bar plot shows that the electricity is more reachable to the urban population and performance is high where electricity is available.

# %%
sns.countplot(x ='Type_of_social_media_used',hue = 'Student_Performance_level', data = df)
plt.show()

# %% [markdown]
# The bar graph clearly describe that the student who does not use social medial has high rate of success.
